# %%
import pandas as pd

coins = pd.read_csv("files/coins_news.csv")

# %%
# Removing symbol and name (equal to id)
coins = coins.drop(["symbol", "name"], axis=1)
# Removing all_time_high, correlation of 1 with current_price
coins = coins.drop("all_time_high(usd)", axis=1)

# %%
# Removing brackets and quotation marks from text fields and replacing NaN with empty string for columns with categorical data

trans_table = str.maketrans("[]'\"","    ")

coins["hashing_algorithm"] = coins["hashing_algorithm"].apply(lambda x: "" if pd.isnull(x) else str(x).translate(trans_table))
coins["categories"] = coins["categories"].apply(lambda x: "" if pd.isnull(x) else str(x).translate(trans_table))
coins["description"] = coins["description"].apply(lambda x: "" if pd.isnull(x) else str(x).translate(trans_table))
coins["homepage_link"] = coins["homepage_link"].apply(lambda x: "" if pd.isnull(x) else str(x).translate(trans_table))
coins["image_url"] = coins["image_url"].apply(lambda x: "" if pd.isnull(x) else str(x).translate(trans_table))
coins["headers"] = coins["headers"].apply(lambda x: "" if pd.isnull(x) else str(x).translate(trans_table))
coins["descriptions"] = coins["descriptions"].apply(lambda x: "" if pd.isnull(x) else str(x).translate(trans_table))
coins["urls"] = coins["urls"].apply(lambda x: "" if pd.isnull(x) else str(x).translate(trans_table))
# Out:
#                   id  block_time_in_minutes hashing_algorithm  \
# 0           aaa-coin                    2.0            Scrypt
# 1           aang-inu                    0.0
# 2               aapl                    0.0
# 3               aave                    0.0
# 4          aave-aave                    0.0
# ...              ...                    ...               ...
# 9574     zzz-finance                    0.0
# 9575  gaia-everworld                    NaN
# 9576         gamerse                    NaN
# 9577         pontoon                    NaN
# 9578       town-star                    NaN
#
#                                              categories genesis_date  \
# 0                                      Cryptocurrency            NaN
# 1                                                                NaN
# 2                                                                NaN
# 3       Polygon Ecosystem ,  Near Protocol Ecosystem...          NaN
# 4                                         Aave Tokens            NaN
# ...                                                 ...          ...
# 9574                                    Yield Farming            NaN
# 9575                                                             NaN
# 9576                                                             NaN
# 9577                                                             NaN
# 9578                                                             NaN
#
#       developer_score  community_score  liquidity_score  \
# 0               0.000            6.932             0.00
# 1               0.000            0.000             0.00
# 2               0.000            8.333             0.00
# 3              48.806           40.136            60.55
# 4               0.000           11.443             1.00
# ...               ...              ...              ...
# 9574            0.000            7.387             0.00
# 9575              NaN              NaN              NaN
# 9576              NaN              NaN              NaN
# 9577              NaN              NaN              NaN
# 9578              NaN              NaN              NaN
#
#                                             description  \
# 0     Speculative PoW / PoS altcoin with CPU mining ...
# 1
# 2     Applescash = YFI + Ampleforth, $AAPL is going ...
# 3     Aave is a decentralized money market protocol ...
# 4
# ...                                                 ...
# 9574  ZZZ is a counter to the a YFI clone OWO. ZZZ a...
# 9575
# 9576
# 9577
# 9578
#
#                               homepage_link  ...  \
# 0                  http://www.aaacoin.us/    ...
# 1              https://www.aanginuerc.com    ...
# 2             https://www.applescash.com/    ...
# 3       https://app.aave.com/?referral=93    ...
# 4                       https://aave.com/    ...
# ...                                     ...  ...
# 9574                 https://zzz.finance/    ...
# 9575                                         ...
# 9576                                         ...
# 9577                                         ...
# 9578                                         ...
#
#                                               image_url  \
# 0     https://assets.coingecko.com/coins/images/9055...
# 1     https://assets.coingecko.com/coins/images/1951...
# 2     https://assets.coingecko.com/coins/images/1236...
# 3     https://assets.coingecko.com/coins/images/1264...
# 4     https://assets.coingecko.com/coins/images/1724...
# ...                                                 ...
# 9574  https://assets.coingecko.com/coins/images/1212...
# 9575
# 9576
# 9577
# 9578
#
#             all_time_high_date    market_cap current_price  \
# 0     2021-08-13T16:50:09.319Z  0.000000e+00  1.225900e-04
# 1     2021-10-27T11:48:50.037Z  0.000000e+00  4.626740e-07
# 2     2020-09-06T00:00:49.729Z  0.000000e+00  3.390840e-01
# 3     2021-05-18T21:19:59.514Z  4.473907e+09  3.381400e+02
# 4     2021-08-17T12:17:43.687Z  0.000000e+00  3.447900e+02
# ...                        ...           ...           ...
# 9574  2020-08-24T03:42:45.784Z  8.452070e+03  7.251740e-01
# 9575                       NaN           NaN           NaN
# 9576                       NaN           NaN           NaN
# 9577                       NaN           NaN           NaN
# 9578                       NaN           NaN           NaN
#
#      price_change_percentage_1y  price_change_percentage_30d  \
# 0                     199.09866                     42.79439
# 1                       0.00000                      0.00000
# 2                     -93.84843                      0.00000
# 3                     869.44154                     23.47592
# 4                       0.00000                     21.46304
# ...                         ...                          ...
# 9574                  -99.21458                      0.00000
# 9575                        NaN                          NaN
# 9576                        NaN                          NaN
# 9577                        NaN                          NaN
# 9578                        NaN                          NaN
#
#       price_change_percentage_7d  \
# 0                       91.94507
# 1                        0.00000
# 2                        0.00000
# 3                        6.70486
# 4                        9.13740
# ...                          ...
# 9574                     0.00000
# 9575                         NaN
# 9576                         NaN
# 9577                         NaN
# 9578                         NaN
#
#                                                 headers  \
# 0
# 1
# 2       Bitcoin s Performance in the Past Decade Was...
# 3       Andre Cronje Suggests Aave Has a Major Vulne...
# 4
# ...                                                 ...
# 9574
# 9575    Polygon-based Multi-Region Fantasy Game Gaia...
# 9576    Warren Buffett Is One of Bitcoin s Biggest C...
# 9577    Hot Cross Unveils First-Ever Offering: Ponto...
# 9578    Can FLOKI, the new dog in town, be the new D...
#
#                                            descriptions  \
# 0
# 1
# 2       Bitcoin (BTC) has not only made history as t...
# 3       Aave and Yearn Finance community members are...
# 4
# ...                                                 ...
# 9574
# 9575
# 9576    The granddaughter of legendary investor and ...
# 9577    With whitelisting already underway, you ll h...
# 9578    The market capitalization of Shiba Inu (SHIB...
#
#                                                    urls
# 0
# 1
# 2       https://coinmarketcap.com/headlines/news/Bit...
# 3       https://cryptobriefing.com/andre-cronje-sugg...
# 4
# ...                                                 ...
# 9574
# 9575    https://cryptobriefing.com/polygon-fantasy-g...
# 9576    https://dailyhodl.com/2021/09/26/warren-buff...
# 9577    https://www.bsc.news/post/hot-cross-unveils-...
# 9578    https://ambcrypto.com/can-floki-the-new-dog-...
#
# [9579 rows x 23 columns]

# %%
# Save to file
coins.to_csv("files/clean_coins.csv")

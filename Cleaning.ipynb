# %%
import pandas as pd

coins = pd.read_csv("files/coins_news.csv")
# Out:
#                      id  symbol                 name  block_time_in_minutes  \
# 77          achain-coin      ac          Achain Coin                    0.0
# 78          acknoledger     ack          AcknoLedger                    0.0
# 152               ageur   ageur                agEUR                    0.0
# 253   alpaca-vault-nftx  alpaca  ALPACA Vault (NFTX)                    0.0
# 312      angle-protocol   angle                ANGLE                    0.0
# ...                 ...     ...                  ...                    ...
# 9538           zoid-pay    zpay              ZoidPay                    0.0
# 9575     gaia-everworld     NaN                  NaN                    NaN
# 9576            gamerse     NaN                  NaN                    NaN
# 9577            pontoon     NaN                  NaN                    NaN
# 9578          town-star     NaN                  NaN                    NaN
#
#      hashing_algorithm                     categories genesis_date  \
# 77                 NaN                             []          NaN
# 78                 NaN                             []          NaN
# 152                NaN                             []          NaN
# 253                NaN  ['Non-Fungible Tokens (NFT)']          NaN
# 312                NaN                             []          NaN
# ...                ...                            ...          ...
# 9538               NaN                             []          NaN
# 9575               NaN                            NaN          NaN
# 9576               NaN                            NaN          NaN
# 9577               NaN                            NaN          NaN
# 9578               NaN                            NaN          NaN
#
#       developer_score  community_score  liquidity_score  ...  \
# 77              0.000            2.610              0.0  ...
# 78              0.000            0.000              0.0  ...
# 152             0.000            0.000              0.0  ...
# 253             0.000            9.430              0.0  ...
# 312            29.017            8.446              0.0  ...
# ...               ...              ...              ...  ...
# 9538            0.000           10.091              1.0  ...
# 9575              NaN              NaN              NaN  ...
# 9576              NaN              NaN              NaN  ...
# 9577              NaN              NaN              NaN  ...
# 9578              NaN              NaN              NaN  ...
#
#      all_time_high(usd)        all_time_high_date  market_cap current_price  \
# 77                  NaN                       NaN         NaN           NaN
# 78                  NaN                       NaN         NaN           NaN
# 152                 NaN                       NaN         NaN           NaN
# 253                 NaN                       NaN         NaN           NaN
# 312                 NaN                       NaN         NaN           NaN
# ...                 ...                       ...         ...           ...
# 9538           0.200013  2021-10-10T16:32:55.484Z  52736435.0           NaN
# 9575                NaN                       NaN         NaN           NaN
# 9576                NaN                       NaN         NaN           NaN
# 9577                NaN                       NaN         NaN           NaN
# 9578                NaN                       NaN         NaN           NaN
#
#      price_change_percentage_1y price_change_percentage_30d  \
# 77                          0.0                         0.0
# 78                          0.0                         0.0
# 152                         0.0                         0.0
# 253                         0.0                         0.0
# 312                         0.0                         0.0
# ...                         ...                         ...
# 9538                        0.0                         0.0
# 9575                        NaN                         NaN
# 9576                        NaN                         NaN
# 9577                        NaN                         NaN
# 9578                        NaN                         NaN
#
#       price_change_percentage_7d  \
# 77                           0.0
# 78                           0.0
# 152                          0.0
# 253                          0.0
# 312                          0.0
# ...                          ...
# 9538                         0.0
# 9575                         NaN
# 9576                         NaN
# 9577                         NaN
# 9578                         NaN
#
#                                                 headers  \
# 77                                                  NaN
# 78                                                  NaN
# 152                                                 NaN
# 253                                                 NaN
# 312                                                 NaN
# ...                                                 ...
# 9538                                                NaN
# 9575  ['Polygon-based Multi-Region Fantasy Game Gaia...
# 9576  ["Warren Buffett Is One of Bitcoin's Biggest C...
# 9577  ['Hot Cross Unveils First-Ever Offering: Ponto...
# 9578  ['Can FLOKI, the new dog in town, be the new D...
#
#                                            descriptions  \
# 77                                                  NaN
# 78                                                  NaN
# 152                                                 NaN
# 253                                                 NaN
# 312                                                 NaN
# ...                                                 ...
# 9538                                                NaN
# 9575                                                 []
# 9576  ['The granddaughter of legendary investor and ...
# 9577  ["With whitelisting already underway, you'll h...
# 9578  ['The market capitalization of Shiba Inu (SHIB...
#
#                                                    urls
# 77                                                  NaN
# 78                                                  NaN
# 152                                                 NaN
# 253                                                 NaN
# 312                                                 NaN
# ...                                                 ...
# 9538                                                NaN
# 9575  ['https://cryptobriefing.com/polygon-fantasy-g...
# 9576  ['https://dailyhodl.com/2021/09/26/warren-buff...
# 9577  ['https://www.bsc.news/post/hot-cross-unveils-...
# 9578  ['https://ambcrypto.com/can-floki-the-new-dog-...
#
# [111 rows x 26 columns]

# %%
# Removing symbol and name (equal to id)
coins = coins.drop(["symbol", "name"], axis=1)

# %%
# Save to file
coins.to_csv("files/clean_coins.csv")
